# %%
# 1. Instalar y configurar Kaggle CLI
# !pip install --quiet kaggle

# 2. Clonar únicamente la carpeta "colab" usando sparse checkout
# !git clone --depth 1 --no-checkout https://github.com/IagooB/federated_test.git
# %cd federated_test
# !git sparse-checkout init --cone
# !git sparse-checkout set colab
# %cd colab

# 3. Subir tu fichero JSON con el identificador de Kaggle (kaggle.json)
from google.colab import files
uploaded = files.upload()  # Selecciona tu kaggle.json

import os
# Mover kaggle.json a ~/.kaggle y ajustar permisos
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)
with open(os.path.expanduser('~/.kaggle/kaggle.json'), 'wb') as f:
    f.write(uploaded['kaggle.json'])
os.chmod(os.path.expanduser('~/.kaggle/kaggle.json'), 0o600)

# 4. Descargar los CSV desde Kaggle a la carpeta data/
# !mkdir -p data
# !kaggle datasets download -d iagobs/label-data -f bi_fed.csv    -p data --unzip
# !kaggle datasets download -d iagobs/label-data -f multi_fed.csv -p data --unzip

# 5. Crear directorios para métricas, pesos y logs
paths = {
    "client_info_dir":         "data/client_info",
    "experiment_log_path":     "data/datos_experimento.csv",
    "guardado_pesos":          "pesos/global_data_multiclase.csv",
    "metrics_log_path":        "metricas/metricas_globales.csv",
    "client_metrics_log_path": "metricas/metricas_por_cliente.csv"
}

for p in [
    paths["client_info_dir"],
    os.path.dirname(paths["experiment_log_path"]),
    os.path.dirname(paths["guardado_pesos"]),
    os.path.dirname(paths["metrics_log_path"]),
    os.path.dirname(paths["client_metrics_log_path"])
]:
    os.makedirs(p, exist_ok=True)
# Out:
# fatal: destination path 'federated_test' already exists and is not an empty directory.
# /content/federated_test
# ...
# /content/federated_test/colab
#      <input type="file" id="files-e33c2c63-3e4d-423c-a450-8a3f41d49043" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e33c2c63-3e4d-423c-a450-8a3f41d49043">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
# %%capture
# !pip install -r /content/federated_test/requirements.txt

# %%
# 6. Ejecutar el script de Flower
# %cd /content/federated_test/colab
# !python run_flwr.py
# Out:
# /content/federated_test/colab
# 2025-06-20 11:47:35.662075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750420055.988390   20470 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750420056.076336   20470 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-20 11:47:36.841687: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
